# %%
# 00_determinism_setup — run FIRST in a fresh kernel (BEFORE importing tensorflow)
import os, sys, random
import numpy as np

SEED = 42

# --- Env vars that must be set BEFORE importing TF ---
os.environ["TF_DETERMINISTIC_OPS"]   = "1"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
os.environ["TF_ENABLE_ONEDNN_OPTS"]  = "0"   # avoid oneDNN nondeterminism on CPU
os.environ["OMP_NUM_THREADS"]        = "1"
os.environ["TF_NUM_INTRAOP_THREADS"] = "1"
os.environ["TF_NUM_INTEROP_THREADS"] = "1"

# Note: PYTHONHASHSEED vendoset në nisje të procesit; në notebook s'e ndryshojmë dot tani.
# Kjo rrallë ndikon, për sa kohë s'varen rezultatet nga rendi i seteve/dikteve.

# --- Seeds for Python, NumPy ---
random.seed(SEED)
np.random.seed(SEED)

# --- Import TF vetëm pasi u vendosën env vars ---
import tensorflow as tf

# Seed për TF/Keras (mbulon initializers, shuffling, dropout, etj.)
try:
    tf.keras.utils.set_random_seed(SEED)   # TF ≥ 2.9
except Exception:
    tf.random.set_seed(SEED)

# Ops deterministike (ku mbështeten)
try:
    tf.config.experimental.enable_op_determinism()
except Exception:
    pass

# Kontrollo fijet brenda TF
try:
    tf.config.threading.set_intra_op_parallelism_threads(1)
    tf.config.threading.set_inter_op_parallelism_threads(1)
except Exception:
    pass

# (Opsionale) fiksim pajisjeje
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"   # vetëm GPU 0
# os.environ["CUDA_VISIBLE_DEVICES"] = ""    # vetëm CPU

# Sigurohu që TF s'ka qenë importuar më herët
if "tensorflow" in sys.modules and sys.modules["tensorflow"] is not tf:
    raise RuntimeError("TensorFlow ishte importuar më parë. Bëj Kernel → Restart pastaj ekzekuto këtë qelizë e para.")

# Info të dobishme për log
print("Determinism setup done.")
print("TF:", tf.__version__, "| NumPy:", np.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# Determinism setup done.
# TF: 2.16.1 | NumPy: 1.26.4
# GPUs: []

# %%
# =============================================
# Bidirectional GRU 24→24 with strong features
# + Country holidays (AL, ME, XK, GR) & weekend
# - Train/Val/Test split by time (70/10/20)
# - Scaler fitted only on TRAIN
# - Extra lags + Fourier seasonality
# - EarlyStopping + ReduceLROnPlateau
# =============================================

import re
import sys, subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
)

# install/import 'holidays' for country calendars
try:
    import holidays
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "holidays"])
    import holidays

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, Bidirectional, LayerNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# -----------------------------
# 0) Reproducibility
# -----------------------------
np.random.seed(42)
tf.random.set_seed(42)

# -----------------------------
# 1) Load & clean data
# -----------------------------
df = pd.read_csv("ost_data_clean.csv", sep=';', engine='python')

# Parse date/time
df['Data'] = pd.to_datetime(df['Data'], errors='coerce')
df['Ora']  = df['Ora'].astype(str).apply(lambda x: re.findall(r'\d+', x)[0]).astype(int).astype(str).str.zfill(2)
df['Datetime'] = pd.to_datetime(df['Data'].dt.strftime('%Y-%m-%d') + ' ' + df['Ora'],
                                format='%Y-%m-%d %H', errors='coerce')
df.set_index('Datetime', inplace=True)
df.dropna(inplace=True)

# Build total cross-border exchange if missing
if 'Shkembimi fizik nderkufitar' not in df.columns:
    for c in ['Shkembimi fizik nderkufitar AL-ME',
              'Shkembimi fizik nderkufitar AL-KS',
              'Shkembimi fizik nderkufitar AL-GR']:
        if c not in df.columns:
            df[c] = 0.0
    df['Shkembimi fizik nderkufitar'] = (
        df['Shkembimi fizik nderkufitar AL-ME'] +
        df['Shkembimi fizik nderkufitar AL-KS'] +
        df['Shkembimi fizik nderkufitar AL-GR']
    )

# Select base features
cols = [
    'Ngarkesa Totale',
    'Prodhimi Total',
    'Shkembimi fizik nderkufitar',
    'Shkembimi fizik nderkufitar AL-ME',
    'Shkembimi fizik nderkufitar AL-KS',
    'Shkembimi fizik nderkufitar AL-GR'
]
df = df[cols].copy()

# -----------------------------
# 1.1) Add calendar features (hour, weekday, weekend, holidays)
# -----------------------------
df['Hour']      = df.index.hour
df['DayOfWeek'] = df.index.dayofweek
df['Weekend']   = (df.index.dayofweek >= 5).astype(int)

def add_country_holidays(frame: pd.DataFrame) -> pd.DataFrame:
    """Add binary holiday flags for AL, ME, XK, GR and combined ANY."""
    years = sorted(frame.index.year.unique())
    idx_dates = pd.Series(frame.index.date, index=frame.index)  # datetime.date

    def flag_for(code, fallback=None):
        try:
            h = holidays.CountryHoliday(code, years=years)
        except Exception:
            # Kosovo sometimes needs explicit class name fallback
            if fallback is not None:
                h = fallback(years=years)
            else:
                h = {}
        return idx_dates.isin(h).astype(int)

    frame['Holiday_AL'] = flag_for('AL')
    frame['Holiday_ME'] = flag_for('ME')
    # Kosovo: try 'XK', fallback to holidays.Kosovo if available
    try:
        frame['Holiday_XK'] = flag_for('XK')
    except Exception:
        # not all versions expose CountryHoliday('XK'); try class
        try:
            frame['Holiday_XK'] = idx_dates.isin(holidays.Kosovo(years=years)).astype(int)
        except Exception:
            frame['Holiday_XK'] = 0
    frame['Holiday_GR'] = flag_for('GR')

    hol_cols = ['Holiday_AL', 'Holiday_ME', 'Holiday_XK', 'Holiday_GR']
    frame['Holiday_ANY'] = frame[hol_cols].max(axis=1).astype(int)
    return frame

df = add_country_holidays(df)

# -----------------------------
# 1.2) Target lags & Fourier seasonality
# -----------------------------
df['lag_1']   = df['Ngarkesa Totale'].shift(1)
df['lag_24']  = df['Ngarkesa Totale'].shift(24)
df['lag_48']  = df['Ngarkesa Totale'].shift(48)
df['lag_168'] = df['Ngarkesa Totale'].shift(168)  # weekly memory

def add_fourier(df_in, tag, period, K=3):
    t = np.arange(len(df_in), dtype=float)
    for k in range(1, K+1):
        df_in[f'{tag}_sin_{period}_{k}'] = np.sin(2*np.pi*k*t/period)
        df_in[f'{tag}_cos_{period}_{k}'] = np.cos(2*np.pi*k*t/period)
    return df_in

df = add_fourier(df, 'fourier_daily', 24,  K=3)
df = add_fourier(df, 'fourier_weekly', 168, K=3)

# Drop NaNs created by lags
df.dropna(inplace=True)

# -----------------------------
# 2) Create sequences 24→24
# -----------------------------
target_col = 'Ngarkesa Totale'
target_idx = df.columns.get_loc(target_col)
n_input  = 24
n_output = 24

def make_sequences(df_frame, n_in=24, n_out=24):
    X, y, future_hours = [], [], []
    idx = df_frame.index
    for i in range(n_in, len(df_frame) - n_out + 1):
        past_block   = df_frame.iloc[i - n_in:i].values
        future_block = df_frame.iloc[i:i + n_out, target_idx].values
        hours        = idx[i:i + n_out].hour.values
        X.append(past_block)
        y.append(future_block)
        future_hours.append(hours)
    return np.array(X), np.array(y), np.array(future_hours)

# Time-based split (70/10/20)
n_total     = len(df)
i_train_end = int(n_total * 0.70)
i_val_end   = int(n_total * 0.80)

df_train = df.iloc[:i_train_end].copy()
df_val   = df.iloc[i_train_end:i_val_end].copy()
df_test  = df.iloc[i_val_end:].copy()

# -----------------------------
# 3) Scaling (fit only on TRAIN)
# -----------------------------
scaler = MinMaxScaler()
scaler.fit(df_train)

df_train_s = pd.DataFrame(scaler.transform(df_train), columns=df.columns, index=df_train.index)
df_val_s   = pd.DataFrame(scaler.transform(df_val),   columns=df.columns, index=df_val.index)
df_test_s  = pd.DataFrame(scaler.transform(df_test),  columns=df.columns, index=df_test.index)

X_train, y_train, hours_train = make_sequences(df_train_s, n_input, n_output)
X_val,   y_val,   hours_val   = make_sequences(df_val_s,   n_input, n_output)
X_test,  y_test,  hours_test  = make_sequences(df_test_s,  n_input, n_output)

input_shape = (X_train.shape[1], X_train.shape[2])

# Helper to inverse only the target column
t_min = scaler.data_min_[target_idx]
t_max = scaler.data_max_[target_idx]
def inv_target(y_scaled):
    return y_scaled * (t_max - t_min) + t_min

# -----------------------------
# 4) Build & train model
# -----------------------------
def build_model():
    units1, units2 = 128, 64
    dr, l2r = 0.35, 1e-4
    model = Sequential([
        Bidirectional(GRU(units=units1, return_sequences=True,
                          kernel_regularizer=l2(l2r),
                          recurrent_regularizer=l2(l2r),
                          bias_regularizer=l2(l2r)),
                      input_shape=input_shape),
        Dropout(dr),
        LayerNormalization(),
        Bidirectional(GRU(units=units2, return_sequences=False,
                          kernel_regularizer=l2(l2r),
                          recurrent_regularizer=l2(l2r),
                          bias_regularizer=l2(l2r))),
        Dropout(dr),
        Dense(24, kernel_regularizer=l2(l2r))
    ])
    opt = Adam(learning_rate=5e-4, clipnorm=1.0)
    model.compile(optimizer=opt, loss='mse')
    return model

model  = build_model()
early  = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
plateau = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5,
                            min_lr=1e-5, verbose=1)

history = model.fit(
    X_train, y_train,
    epochs=80,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[early, plateau],
    verbose=1
)

# -----------------------------
# 5) Loss curve 
# -----------------------------
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve during Training (MSE)')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.grid(True); plt.legend()
plt.savefig("loss_curve_bidirectional_GRU.png", dpi=600, bbox_inches='tight')
plt.show()

# -----------------------------
# 6) Predict & inverse-transform
# -----------------------------
y_pred_test = model.predict(X_test, verbose=0)
y_test_res  = inv_target(y_test)
y_pred_res  = inv_target(y_pred_test)

# -----------------------------
# 7) Metrics (TEST)
# -----------------------------
def evaluate(y_true_2d, y_pred_2d, tag):
    yt = y_true_2d.reshape(-1)
    yp = y_pred_2d.reshape(-1)
    mae  = mean_absolute_error(yt, yp)
    rmse = mean_squared_error(yt, yp, squared=False)
    eps  = 1e-6
    yt_safe = np.where(yt == 0, eps, yt)
    mape = mean_absolute_percentage_error(yt_safe, yp) * 100
    r2   = r2_score(yt, yp)
    acc  = 100 - mape
    print(f"[{tag}] MAE: {mae:.2f} | RMSE: {rmse:.2f} | MAPE: {mape:.2f}% | R²: {r2:.4f} | Accuracy: {acc:.2f}%")
    return mae, rmse, mape, r2, acc

print("\n--- Metrics on TEST ---")
evaluate(y_test_res, y_pred_res, "Bidirectional GRU (+ Holidays)")

# -----------------------------
# 8) 24-hour forecast plot (first test sample) 
# -----------------------------
plt.figure(figsize=(12,5))
plt.plot(y_test_res[0], label='Actual')
plt.plot(y_pred_res[0], label='Prediction')
plt.title('24-hour Forecast (First Test Sample)')
plt.xlabel('Hour'); plt.ylabel('Total Load (MW)')
plt.grid(True); plt.legend()
plt.savefig("forecast_first_sample_bidirectional_GRU.png", dpi=600, bbox_inches='tight')
plt.show()
# Out:
# Epoch 1/80
# C:\Users\Alketa\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 23s 133ms/step - loss: 0.4086 - val_loss: 0.1347 - learning_rate: 5.0000e-04
# Epoch 2/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.1171 - val_loss: 0.1342 - learning_rate: 5.0000e-04
# Epoch 3/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - loss: 0.0937 - val_loss: 0.1228 - learning_rate: 5.0000e-04
# Epoch 4/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0804 - val_loss: 0.1111 - learning_rate: 5.0000e-04
# Epoch 5/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0704 - val_loss: 0.1032 - learning_rate: 5.0000e-04
# Epoch 6/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0623 - val_loss: 0.0942 - learning_rate: 5.0000e-04
# Epoch 7/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - loss: 0.0561 - val_loss: 0.0921 - learning_rate: 5.0000e-04
# Epoch 8/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0509 - val_loss: 0.0872 - learning_rate: 5.0000e-04
# Epoch 9/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - loss: 0.0466 - val_loss: 0.0796 - learning_rate: 5.0000e-04
# Epoch 10/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0435 - val_loss: 0.0738 - learning_rate: 5.0000e-04
# Epoch 11/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0401 - val_loss: 0.0682 - learning_rate: 5.0000e-04
# Epoch 12/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0372 - val_loss: 0.0627 - learning_rate: 5.0000e-04
# Epoch 13/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0345 - val_loss: 0.0604 - learning_rate: 5.0000e-04
# Epoch 14/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - loss: 0.0322 - val_loss: 0.0523 - learning_rate: 5.0000e-04
# Epoch 15/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 131ms/step - loss: 0.0297 - val_loss: 0.0505 - learning_rate: 5.0000e-04
# Epoch 16/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 130ms/step - loss: 0.0278 - val_loss: 0.0447 - learning_rate: 5.0000e-04
# Epoch 17/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0260 - val_loss: 0.0370 - learning_rate: 5.0000e-04
# Epoch 18/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 131ms/step - loss: 0.0245 - val_loss: 0.0348 - learning_rate: 5.0000e-04
# Epoch 19/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 130ms/step - loss: 0.0226 - val_loss: 0.0334 - learning_rate: 5.0000e-04
# Epoch 20/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0213 - val_loss: 0.0292 - learning_rate: 5.0000e-04
# Epoch 21/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - loss: 0.0200 - val_loss: 0.0295 - learning_rate: 5.0000e-04
# Epoch 22/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - loss: 0.0189 - val_loss: 0.0252 - learning_rate: 5.0000e-04
# Epoch 23/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0178 - val_loss: 0.0237 - learning_rate: 5.0000e-04
# Epoch 24/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0169 - val_loss: 0.0230 - learning_rate: 5.0000e-04
# Epoch 25/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0159 - val_loss: 0.0207 - learning_rate: 5.0000e-04
# Epoch 26/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0152 - val_loss: 0.0186 - learning_rate: 5.0000e-04
# Epoch 27/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0145 - val_loss: 0.0171 - learning_rate: 5.0000e-04
# Epoch 28/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0137 - val_loss: 0.0162 - learning_rate: 5.0000e-04
# Epoch 29/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0133 - val_loss: 0.0161 - learning_rate: 5.0000e-04
# Epoch 30/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0124 - val_loss: 0.0141 - learning_rate: 5.0000e-04
# Epoch 31/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0120 - val_loss: 0.0126 - learning_rate: 5.0000e-04
# Epoch 32/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0115 - val_loss: 0.0126 - learning_rate: 5.0000e-04
# Epoch 33/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0110 - val_loss: 0.0116 - learning_rate: 5.0000e-04
# Epoch 34/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0106 - val_loss: 0.0114 - learning_rate: 5.0000e-04
# Epoch 35/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0100 - val_loss: 0.0111 - learning_rate: 5.0000e-04
# Epoch 36/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0097 - val_loss: 0.0107 - learning_rate: 5.0000e-04
# Epoch 37/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0093 - val_loss: 0.0111 - learning_rate: 5.0000e-04
# Epoch 38/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0090 - val_loss: 0.0101 - learning_rate: 5.0000e-04
# Epoch 39/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0087 - val_loss: 0.0100 - learning_rate: 5.0000e-04
# Epoch 40/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0084 - val_loss: 0.0104 - learning_rate: 5.0000e-04
# Epoch 41/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 124ms/step - loss: 0.0082 - val_loss: 0.0102 - learning_rate: 5.0000e-04
# Epoch 42/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0079 - val_loss: 0.0096 - learning_rate: 5.0000e-04
# Epoch 43/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0077 - val_loss: 0.0095 - learning_rate: 5.0000e-04
# Epoch 44/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0075 - val_loss: 0.0090 - learning_rate: 5.0000e-04
# Epoch 45/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 124ms/step - loss: 0.0073 - val_loss: 0.0085 - learning_rate: 5.0000e-04
# Epoch 46/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0072 - val_loss: 0.0083 - learning_rate: 5.0000e-04
# Epoch 47/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0070 - val_loss: 0.0084 - learning_rate: 5.0000e-04
# Epoch 48/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0068 - val_loss: 0.0090 - learning_rate: 5.0000e-04
# Epoch 49/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0066 - val_loss: 0.0085 - learning_rate: 5.0000e-04
# Epoch 50/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0066 - val_loss: 0.0082 - learning_rate: 5.0000e-04
# Epoch 51/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0064 - val_loss: 0.0080 - learning_rate: 5.0000e-04
# Epoch 52/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0063 - val_loss: 0.0082 - learning_rate: 5.0000e-04
# Epoch 53/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0062 - val_loss: 0.0080 - learning_rate: 5.0000e-04
# Epoch 54/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0061 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 55/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0061 - val_loss: 0.0076 - learning_rate: 5.0000e-04
# Epoch 56/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 126ms/step - loss: 0.0060 - val_loss: 0.0073 - learning_rate: 5.0000e-04
# Epoch 57/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0059 - val_loss: 0.0074 - learning_rate: 5.0000e-04
# Epoch 58/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0058 - val_loss: 0.0074 - learning_rate: 5.0000e-04
# Epoch 59/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0057 - val_loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 60/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 124ms/step - loss: 0.0058 - val_loss: 0.0073 - learning_rate: 5.0000e-04
# Epoch 61/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0057
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 126ms/step - loss: 0.0057 - val_loss: 0.0077 - learning_rate: 5.0000e-04
# Epoch 62/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 126ms/step - loss: 0.0056 - val_loss: 0.0072 - learning_rate: 2.5000e-04
# Epoch 63/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0055 - val_loss: 0.0072 - learning_rate: 2.5000e-04
# Epoch 64/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0055 - val_loss: 0.0072 - learning_rate: 2.5000e-04
# Epoch 65/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0054 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 66/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0054 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 67/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0054 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 68/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0053 - val_loss: 0.0069 - learning_rate: 2.5000e-04
# Epoch 69/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step - loss: 0.0053 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 70/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0053
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0053 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 71/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0052 - val_loss: 0.0073 - learning_rate: 1.2500e-04
# Epoch 72/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - loss: 0.0052 - val_loss: 0.0074 - learning_rate: 1.2500e-04
# Epoch 73/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0052 - val_loss: 0.0074 - learning_rate: 1.2500e-04
# Epoch 74/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0051 - val_loss: 0.0072 - learning_rate: 1.2500e-04
# Epoch 75/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0051
# Epoch 75: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0051 - val_loss: 0.0071 - learning_rate: 1.2500e-04
# Epoch 76/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0051 - val_loss: 0.0069 - learning_rate: 6.2500e-05
# Epoch 77/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 132ms/step - loss: 0.0051 - val_loss: 0.0069 - learning_rate: 6.2500e-05
# Epoch 78/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - loss: 0.0051 - val_loss: 0.0070 - learning_rate: 6.2500e-05
# Epoch 79/80
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - loss: 0.0051 - val_loss: 0.0070 - learning_rate: 6.2500e-05
# Epoch 80/80
# 122/123 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0050
# Epoch 80: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - loss: 0.0050 - val_loss: 0.0070 - learning_rate: 6.2500e-05
# --- Metrics on TEST ---
# [Bidirectional GRU (+ Holidays)] MAE: 77.91 | RMSE: 100.63 | MAPE: 15.50% | R²: 0.7621 | Accuracy: 84.50%
# C:\Users\Alketa\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# ============================================================
# 9) HYBRID STEP: Train XGBoost on GRU residuals (24 models)
#     - Append-only block for Jupyter; does NOT modify earlier code
# ============================================================
 
# 9.1) Determinism extras for XGBoost (safe even if already set)
import os, numpy as np
SEED = 42
np.random.seed(SEED)
os.environ.setdefault("OMP_NUM_THREADS", "1")  # single-thread XGB for determinism

# 9.2) Ensure xgboost is available
try:
    from xgboost import XGBRegressor
except ImportError:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "xgboost"])
    from xgboost import XGBRegressor

# 9.3) Predictions on TRAIN/VAL (to build residual targets)
y_pred_tr  = model.predict(X_train, verbose=0)
y_pred_va  = model.predict(X_val,   verbose=0)

# inverse-transform ONLY the target
y_tr_true  = inv_target(y_train)     # (Ntr, 24)
y_va_true  = inv_target(y_val)       # (Nva, 24)
y_te_true  = y_test_res              # (Nte, 24)  # already computed above

y_tr_pred  = inv_target(y_pred_tr)
y_va_pred  = inv_target(y_pred_va)
y_te_pred  = y_pred_res              # already computed above

# Residuals to learn: r = y_true − y_pred
res_tr = y_tr_true - y_tr_pred
res_va = y_va_true - y_va_pred

# 9.4) Build per-horizon tabular features from the UN-SCALED engineered frame (df)
# We need timestamps for each horizon window to fetch rows from `df`.
def make_times(df_frame, n_in=24, n_out=24):
    idx = df_frame.index
    times = []
    for i in range(n_in, len(df_frame) - n_out + 1):
        times.append(idx[i:i+n_out].values)
    return np.array(times)

times_train = make_times(df_train, n_input, n_output)
times_val   = make_times(df_val,   n_input, n_output)
times_test  = make_times(df_test,  n_input, n_output)

# Features for XGB: use ALL engineered cols EXCEPT the target itself
xgb_feat_cols = [c for c in df.columns if c != target_col]

def rows_to_features(times_2d, frame, cols):
    """Fetch feature rows at target timestamps for each horizon."""
    N, H = times_2d.shape
    out = []
    for i in range(N):
        # .loc over a DatetimeIndex slice with numpy timestamps
        rows = frame.loc[pd.to_datetime(times_2d[i])].reindex(columns=cols).values  # (H, F)
        out.append(rows)
    return np.array(out)  # (N, H, F)

X_tab_tr = rows_to_features(times_train, df, xgb_feat_cols)
X_tab_va = rows_to_features(times_val,   df, xgb_feat_cols)
X_tab_te = rows_to_features(times_test,  df, xgb_feat_cols)

Ntr, H, F = X_tab_tr.shape
Nva       = X_tab_va.shape[0]
Nte       = X_tab_te.shape[0]

# 9.5) Train 24 XGB models (one per horizon)
xgb_models = []
for h in range(H):
    Xh_tr = X_tab_tr[:, h, :]      # (Ntr, F)
    yh_tr = res_tr[:, h]           # residuals (Ntr,)

    model_h = XGBRegressor(
        n_estimators=700,
        learning_rate=0.04,
        max_depth=6,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_lambda=1.0,
        min_child_weight=1,
        tree_method="hist",        # deterministic CPU histogram
        grow_policy="depthwise",
        n_jobs=1,                  # single-thread for deterministic reductions
        random_state=SEED
    )
    model_h.fit(Xh_tr, yh_tr, verbose=False)
    xgb_models.append(model_h)

# 9.6) Hybrid prediction on TEST: GRU + residual correction from XGB
res_hat_te = np.zeros_like(y_te_pred)    # (Nte, 24)
for h in range(H):
    Xh_te = X_tab_te[:, h, :]
    res_hat_te[:, h] = xgb_models[h].predict(Xh_te)

y_te_hybrid = y_te_pred + res_hat_te     # corrected forecast in MW

# ============================================================
# 10) Metrics & Plots (600 dpi)
# ============================================================
def eval_metrics(y_true_2d, y_pred_2d, tag):
    yt = y_true_2d.reshape(-1); yp = y_pred_2d.reshape(-1)
    mae  = mean_absolute_error(yt, yp)
    rmse = mean_squared_error(yt, yp, squared=False)
    eps  = 1e-6
    yt_safe = np.where(yt == 0, eps, yt)
    mape = mean_absolute_percentage_error(yt_safe, yp) * 100
    r2   = r2_score(yt, yp)
    acc  = 100 - mape
    print(f"[{tag}] MAE: {mae:.2f} | RMSE: {rmse:.2f} | MAPE: {mape:.2f}% | R²: {r2:.4f} | Accuracy: {acc:.2f}%")
    return mae, rmse, mape, r2, acc

print("\n--- HYBRID EVALUATION (TEST) ---")
m_gru     = eval_metrics(y_te_true, y_te_pred,   "Bidirectional GRU")
m_hybrid  = eval_metrics(y_te_true, y_te_hybrid, "Hybrid (GRU + XGB residual)")

# (a) 24-hour forecast comparison for FIRST test sample
plt.figure(figsize=(12,5))
plt.plot(y_te_true[0],   label='Actual')
plt.plot(y_te_pred[0],   label='GRU')
plt.plot(y_te_hybrid[0], label='Hybrid (GRU + XGB)')
plt.title('24-hour Forecast (First Test Sample)')
plt.xlabel('Hour'); plt.ylabel('Total Load (MW)')
plt.grid(True); plt.legend()
plt.savefig("hybrid_forecast_first_sample_bidirectional_GRU_XGB.png", dpi=600, bbox_inches='tight')
plt.show()

# (b) Residual distributions: GRU vs Hybrid
plt.figure(figsize=(10,4))
plt.hist((y_te_true - y_te_pred).reshape(-1),   bins=60, alpha=0.6, label='GRU residuals')
plt.hist((y_te_true - y_te_hybrid).reshape(-1), bins=60, alpha=0.6, label='Hybrid residuals')
plt.title('Residual Distribution: GRU vs Hybrid')
plt.xlabel('Error (MW)'); plt.ylabel('Count')
plt.legend(); plt.grid(True)
plt.savefig("residuals_distribution_hybrid_from_bidirectional_GRU_XGB.png", dpi=600, bbox_inches='tight')
plt.show()

# (c) Bar chart of metrics (RMSE/MAE/MAPE)
labels = ['MAE','RMSE','MAPE','R²']
gru_vals    = [m_gru[0], m_gru[1], m_gru[2], m_gru[3]]
hyb_vals    = [m_hybrid[0], m_hybrid[1], m_hybrid[2], m_hybrid[3]]

plt.figure(figsize=(8,5))
x = np.arange(len(labels))
w = 0.35
plt.bar(x - w/2, gru_vals, width=w, label='GRU')
plt.bar(x + w/2, hyb_vals, width=w, label='Hybrid')
plt.xticks(x, labels)
plt.title('Metrics: GRU vs Hybrid on TEST')
plt.grid(True, axis='y')
plt.legend()
plt.savefig("metrics_comparison_gru_vs_hybrid.png", dpi=600, bbox_inches='tight')
plt.show()
# Out:
# --- HYBRID EVALUATION (TEST) ---
# [Bidirectional GRU] MAE: 77.91 | RMSE: 100.63 | MAPE: 15.50% | R²: 0.7621 | Accuracy: 84.50%
# [Hybrid (GRU + XGB residual)] MAE: 63.25 | RMSE: 81.50 | MAPE: 12.10% | R²: 0.8439 | Accuracy: 87.90%
# C:\Users\Alketa\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Alketa\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import subprocess, sys
with open("requirements_lock.txt","w") as f:
    f.write(subprocess.check_output([sys.executable,"-m","pip","freeze"]).decode())
